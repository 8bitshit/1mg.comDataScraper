# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup as soup

# %%
header = {'Origin': 'https://www.1mg.com',
          'Referer': 'https://www.1mg.com/categories/exclusive/immunity-boosters/vitamin-c-734',
          'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36'}

# %%
url = 'https://www.1mg.com/categories/exclusive/immunity-boosters/vitamin-c-734'

# %%
html = requests.get(url = url, headers = header)
html.status_code  #checking if request was successful, status code must evaluate to 200, otherwise request has failed

# %%
bsobj = soup(html.content, 'html.parser')
bsobj

# %%
prod_name_output = bsobj.findAll('div', {'class': 'style__pro-title___2QwJy'})
pack_size_output = bsobj.findAll('div', {'class': 'style__pack-size___2JQG7'})
prod_price_output = bsobj.findAll('div', {'class': 'style__price-tag___cOxYc'})

# %%
product_name = []
for name in prod_name_output:
    product_name.append(name.text.strip())

product_name

# %%
package_size = []
for name in pack_size_output:
    package_size.append(name.text.strip())

package_size

# %%
product_price = []
for price in prod_price_output:
    product_price.append(format(float(price.text.replace('₹', '').strip()), '.2f'))

product_price

# %%
df_dict = {'pname': product_name, 
           'psize': package_size,
           'pprice': product_price}

# %%
df = pd.DataFrame.from_dict(df_dict)
df = df.rename(columns={'pname': 'Product name', 'psize': 'Package size', 'pprice': 'Price'})
df
# Out:
#                                          Product name  \
# 0                    MaxCee Vitamin C Chewable Tablet
# 1   Fast&Up Charge Natural Vitamin C & Zinc Efferv...
# 2   Chicnutrix Combo Pack of Glow Effervescent Tab...
# 3                Purayati Vitamin C Vegetarian Tablet
# 4      Zingavita Vitamin C Amla Extract 1000mg Tablet
# 5   1mg Vitamin C+Vitamin D3, Zinc and Amla Extrac...
# 6   Chicnutrix Super C with Vitamin C, Amla Extrac...
# 7                       Limcee Chewable Tablet Orange
# 8   Chicnutrix Super C with Vitamin C, Amla Extrac...
# 9      Dr. Morepen Natural Vitamin-C with Zinc Tablet
# 10        Herbs & Health Vitamin C Vegetarian Capsule
# 11    Nature's Velvet Natural Vitamin C 500mg Capsule
# 12                   Alron-Z Capsule Buy 1 Get 1 Free
# 13  Cimune SF Vitamin C and Zinc Sugar Free Chewab...
# 14  Origins Nutra Actifiz Amla Extract with Vitami...
# 15  Fast&Up Charge Natural Vitamin C & Zinc Orange...
# ...
